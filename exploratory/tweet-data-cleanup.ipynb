# %%
import pandas as pd

tweets_df = pd.concat([pd.read_json('../dataset/tweet-processed.json', orient='index'), pd.read_excel('../dataset/tweet-label.xlsx').drop(['Unnamed: 0', 'raw_text', 'is_spam'], axis=1)], axis=1)
tweets_df.head()
# Out:
#                                             raw_text  \
# 0                      cepet bgt si…. #10YearsOf5SOS
# 1  Hallo Guys semoga kalian sehat selalu\n\nYang ...
# 2  #10YearsOf5SOS udah 10 tahun ajaa time flies.....
# 3  Ashton mi nene\n#BackTo2011 #10YearsOf5SOS  #5...
# 4  MYT mohegan sun, 2018 💖 #10YearsOf5SOS #5SOS h...
#
#                                    1st_clean_twitter  \
# 0                      cepet bgt si….  10YearsOf5SOS
# 1  Hallo Guys semoga kalian sehat selalu\n\nYang ...
# 2   10YearsOf5SOS udah 10 tahun ajaa time flies.....
# 3  Ashton mi nene\n BackTo2011  10YearsOf5SOS   5...
# 4      MYT mohegan sun, 2018 💖  10YearsOf5SOS  5SOS
#
#                             1st_clean_twitter_gensim  \
# 0                                    cepet bgt si….
# 1  Hallo Guys semoga kalian sehat selalu\n\nYang ...
# 2   udah 10 tahun ajaa time flies.. eh tapi aku b...
# 3                               Ashton mi nene\n
# 4                         MYT mohegan sun, 2018 💖
#
# ...

# %%
tweets_df.dropna(inplace=True)

# %%
emotion_translate = {
    's': 'sad',
    'h': 'happy',
    'o': 'hopeful',
    'a': 'angry',
    'd': 'disgust',
    'n': 'neutral',
    'p': 'surprise',
    'w': 'funny',
    'f': 'fear'
}

tweets_df['emotion'] = tweets_df['emotion'].map(emotion_translate)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

plt.figure(figsize=(16,9))
sns.histplot(tweets_df, x='emotion', hue='emotion')
plt.show()

# %%
tweets_df
# Out:
#                                                raw_text  \
# 0                         cepet bgt si…. #10YearsOf5SOS
# 2     #10YearsOf5SOS udah 10 tahun ajaa time flies.....
# 5     NANGIS BGT 2011 ENAK BANGET ALLAHUU NGINGETIN ...
# 7     Liriknya itu loooo🥺😭\n#10YearsOf5SOS https://t...
# 8     happy #10YearsOf5sos \n\n5sosfam itu fandom ke...
# ...                                                 ...
# 3744  maaf pak/bu kameramen sblmnya saya mau nanya k...
# 3752  JUNGKOOK LOVE U LO NUTUPIN ABS PAS FAKE LOVE T...
# 3771  @yerimwiyese IYAA PDHL MSI DIPANGGUNG, ITU PAS...
# 3772                        BST x FAKE LOVE emg terbaik
# 3836  @BadmintonTalk Semifinal menanti semngat 💪💪 gr...
#
#                                       1st_clean_twitter  \
# 0                         cepet bgt si….  10YearsOf5SOS
# 2      10YearsOf5SOS udah 10 tahun ajaa time flies.....
# 5     NANGIS BGT 2011 ENAK BANGET ALLAHUU NGINGETIN ...
# 7                 Liriknya itu loooo🥺😭\n 10YearsOf5SOS
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_test = train_test_split(tweets_df.drop('emotion', axis=1), tweets_df['emotion'], random_state=42)

# %%
pd.Series(y_train).value_counts().values
# Out:
# array([181,  33,  28,  23,  23,  22,  13,  10,   9], dtype=int64)

# %%
plt.figure(figsize=(16,9))
sns.histplot(y_train)
# Out:
# <AxesSubplot:xlabel='emotion', ylabel='Count'>

# %%
plt.figure(figsize=(16,9))
sns.histplot(y_test)
# Out:
# <AxesSubplot:xlabel='emotion', ylabel='Count'>

# %%
tweets_df.to_json('../dataset/tweet-cleaned.json', orient='index')
